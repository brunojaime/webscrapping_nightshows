# %%
import requests
from bs4 import BeautifulSoup as bs

# %%
#Konex
url = "https://www.cckonex.org/"
#url = "https://entradas.cckonex.org/event/cumbia-konex-001"
requests.get(url)
#html = requests.get(url).text
#soup = BeautifulSoup(html,'html5lib')
#requests.get(url)
# Out:
# <Response [200]>

# %%
html = requests.get(url)
type(html)
html.status_code
# Out:
# 200

# %%
# Parseamos la información. Le damos el formato deseado
soup = bs(html.content,"html.parser")

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html class="loading2" lang="es">
# <head>
# <meta charset="utf-8"/><link as="style" href="https://www.cckonex.org/wp-content/cache/fvm/min/1712342300-css622238e7eacdc5123c2a25c65b73d72d77731382aafe62f64ccb5bf9bbe05.css" media="all" rel="preload"/>
# <link as="style" href="https://www.cckonex.org/wp-content/cache/fvm/min/1712342300-cssee33070cf780e81644a2cf3b03e94c949b1d88a389787324ac71793a0dd88.css" media="all" rel="preload"/>
# <link as="style" href="https://www.cckonex.org/wp-content/cache/fvm/min/1712342300-css26d9795abe21eb606d608dcfefa004ab350d446950e05d8da48cbe1517d3d.css" media="all" rel="preload"/>
# <link as="style" href="https://www.cckonex.org/wp-content/cache/fvm/min/1712342300-css538a7f09206bfb09e10e1411212741092795bd16422d93d2ca275194774f4.css" media="all" rel="preload"/>
# ...

# %%
#div = soup.find('div', class_='seccion contenido')
div = soup.find('div',id_='page')
#for child in div.children:
    #print(child)

# %%
def reemplazar_caracteres(text_in,caracteres):
     for caracter in caracteres:
          for entrada in caracter['in']:
               if entrada in text_in:
                    text_in = text_in.replace(entrada,caracter['out'])
     print(text_in)
     return text_in

def validar_url(url_general, url_especifica):
     while (url_especifica!=""):
          url_completa = f"{url_general}{url_especifica}"
          if (requests.get(url_completa).status_code==200):
               return url_completa
          else:
               palabras = url_especifica.split("-")[:-1]
               url_especifica = '-'.join(palabras)
               print(url_especifica)
     return 0

# %%
import unicodedata

def obtener_url_final(url_entrada):
    
    url_entrada = url_entrada.strip().lower()
    caracteres_invalidos= [":",".",","]
    url_sin_acentos = ''.join((c for c in unicodedata.normalize('NFD', url_entrada)
                             if unicodedata.category(c) != 'Mn'))

    caracteres_especiales =[

        {"in":[" "],"out": "-"}
        ]
    
    url_final= reemplazar_caracteres(url_sin_acentos,caracteres_especiales)
    url_final =validar_url(url, url_final)   
    return url_final

# %%
# Asumiendo que `html` es tu documento HTML ya cargado como string
import re
from datetime import datetime

soup = bs(html.text, 'html.parser')
def obtener_fecha(fecha_str):
    fecha_upper = fecha_str.upper()
    dia = obtener_dia(fecha_upper)
    mes = obtener_mes(fecha_upper)
    anio = datetime.now().year
    return f"{dia}/{mes}/{anio}"



def obtener_dia(fecha_str):
    numeros = re.findall(r'\d+',fecha_str)
    if numeros:
        return numeros[0]
    else:
        return None
def obtener_mes(fecha_str):
    meses = {
        'ENERO': 1, 'FEBRERO': 2, 'MARZO': 3, 'ABRIL': 4, 'MAYO': 5, 'JUNIO': 6,
        'JULIO': 7, 'AGOSTO': 8, 'SEPTIEMBRE': 9, 'OCTUBRE': 10, 'NOVIEMBRE': 11, 'DICIEMBRE': 12
    }
    
    for palabra in fecha_str.split():
        if palabra in meses:
            return  meses[palabra]
    
    return None  
# Encuentra todos los divs que contienen la clase "espectaculo"
espectaculos = soup.find_all('div', class_='espectaculo')
espectaculos_list = [
    {
        "categoria":espectaculo.find('div',class_= 'categoria').text.strip(),
        'nombre' :espectaculo.find('div',class_= 'nombre').text.strip().upper(),
        'fecha': obtener_fecha(espectaculo.find('p').text.strip()),
        "hora": espectaculo.find_all('p')[1].text.strip(),
        "url": obtener_url_final(espectaculo.find('div',class_= 'nombre').text)         
    }
    for espectaculo in espectaculos
]

espectaculos_list
# Out:
# cumbia-konex
# la-bomba-de-tiempo
# alfa-mist
# fiesta-bomba-de-cumpleanos
# fiesta-bomba-de
# nite-lite-club
# dancing-mood
# furia-fest
# erica-rivas-y-martin-rechimuzzi-presentan:-¿que-pasa-hoy-aca?
# erica-rivas-y-martin-rechimuzzi-presentan:-¿que-pasa-hoy
# erica-rivas-y-martin-rechimuzzi-presentan:-¿que-pasa
# erica-rivas-y-martin-rechimuzzi-presentan:-¿que
# erica-rivas-y-martin-rechimuzzi-presentan:
# cuerpo-adentro
# mover-la-lengua-+-marcar-como-leido
# mover-la-lengua-+-marcar-como
# mover-la-lengua-+-marcar
# mover-la-lengua-+
# caribe
# recital-de-mitos
# yamandu-costa
# armyfest
# alter-v
# soliloquio
#
# antivisita-formas-de-entrar-y-salir-de-la-esma
# antivisita-formas-de-entrar-y-salir-de-la
# antivisita-formas-de-entrar-y-salir-de
# antivisita-formas-de-entrar-y-salir
# antivisita-formas-de-entrar-y
# antivisita-formas-de-entrar
# antivisita-formas-de
# antivisita-formas
# antivisita
# vomit
# wayqeycuna
# ametralladora
# mega-rose
# pulse:-tributo-a-pink-floyd
# ...

# %%
def imprimir_precio(soup):
    try:
        show = soup.find_all('li',class_='dato_entradas')

        for sho in show:
                este_show = sho.find_all('p')
                return(este_show)
    except:
         return "No se encontró"

# %%
espec = espectaculos_list
for espectaculo in espec: 
    html = requests.get(espectaculo['url'])
    soup = bs(html.content,"html.parser")
    print(imprimir_precio(soup))
# Out:
# None
# [<p>Anticipada $6.000 + service charge | Día del show $8.000 + service charge | Puerta $10.000 + service charge</p>]
# [<p>Preventa $37.500 + service charge</p>]
# None
# [<p>Preventa $4000 + service charge | Anticipadas $4500 + service charge | Puerta $5000</p>]
# [<p>1° Preventa $6.000 + service charge | 2° Preventa $7.000 + service charge | Anticipadas $8.000 +service charge | General $9.000 + service charge | Puerta $10.000 + service charge</p>]
# [<p>Desde $4900 + service charge</p>]
# [<p>Entradas desde $10.000 + service charge</p>]
# [<p>Entradas desde $14.000 + service charge</p>]
# [<p>Preventa $4000 + service charge | Anticipadas $6000 | Día del show $7000 + service charge</p>]
# [<p>General $8.000 + service charge</p>]
# [<p>General $8.000 + service charge</p>]
# [<p>Preventa $12.000 + service charge | Anticipadas $16.000 + service charge | Puerta $20.000 + service charge</p>]
# ...

# %%
espectaculos
# Out:
# [<div class="site" id="page">
#  <a class="skip-link screen-reader-text" href="#content">Skip to content</a>
#  <header class="site-header navbar navbar-static-top navbar-fixed-top" role="banner">
#  <div class="container">
#  <div class="row">
#  <div class="col-xs-12">
#  <div class="navbar-header">
#  <button class="navbar-toggle" data-target=".navbar-collapse" data-toggle="collapse" type="button">
#  <span class="sr-only">Toggle navigation</span>
#  <span class="icon-bar"></span>
#  <span class="icon-bar"></span>
#  <span class="icon-bar"></span>
#  </button>
#  <div class="navbar-brand">
#  <a class="site-logo logo_header" href="https://www.cckonex.org/">
# ...

# %%
import pandas as pd

df = pd.DataFrame(espectaculos_list)
df
# Out:
#        categoria                                             nombre  \
# 0      Trasnoche                                       CUMBIA KONEX
# 1         Música                                 LA BOMBA DE TIEMPO
# 2         Música                                          ALFA MIST
# 3      Trasnoche                         FIESTA BOMBA DE CUMPLEAÑOS
# 4   Experiencias                                     NITE-LITE CLUB
# 5         Música                                       DANCING MOOD
# 6      Trasnoche                                         FURIA FEST
# 7         Teatro  ÉRICA RIVAS Y MARTÍN RECHIMUZZI PRESENTAN: ¿QU...
# 8   Experiencias                                     CUERPO ADENTRO
# 9      Escénicas                MOVER LA LENGUA + MARCAR COMO LEÍDO
# 10     Escénicas                                             CARIBE
# 11         Ideas                                   RECITAL DE MITOS
# 12        Música                                      YAMANDÚ COSTA
# ...

# %%
#for espectaculo in espectaculos:
 #   print(espectaculo)
'''
# Itera a través de cada espectaculo y extrae la información
for espectaculo in espectaculos:
    # Accede a la categoría del espectáculo
    categoria = espectaculo.find('div', class_='categoria').text.strip()
    
    # Accede al nombre del espectáculo
    nombre = espectaculo.find('div', class_='nombre').text.strip()
    
    # Accede a los párrafos con las fechas y horas
    informacion = espectaculo.find('div', class_='informacion')
    fecha = informacion.find_all('p')[0].text.strip() if informacion.find_all('p') else ''
    hora = informacion.find_all('p')[1].text.strip() if len(informacion.find_all('p')) > 1 else ''
    
    # Imprimir la información
    print(f"Categoría: {categoria}, Nombre: {nombre}, Fecha: {fecha}, Hora: {hora}")
'''
# Out:
# '\n# Itera a través de cada espectaculo y extrae la información\nfor espectaculo in espectaculos:\n    # Accede a la categoría del espectáculo\n    categoria = espectaculo.find(\'div\', class_=\'categoria\').text.strip()\n    \n    # Accede al nombre del espectáculo\n    nombre = espectaculo.find(\'div\', class_=\'nombre\').text.strip()\n    \n    # Accede a los párrafos con las fechas y horas\n    informacion = espectaculo.find(\'div\', class_=\'informacion\')\n    fecha = informacion.find_all(\'p\')[0].text.strip() if informacion.find_all(\'p\') else \'\'\n    hora = informacion.find_all(\'p\')[1].text.strip() if len(informacion.find_all(\'p\')) > 1 else \'\'\n    \n    # Imprimir la información\n    print(f"Categoría: {categoria}, Nombre: {nombre}, Fecha: {fecha}, Hora: {hora}")\n'

# %%
from bs4 import BeautifulSoup

# Supongamos que 'html_content' es tu HTML
soup = bs(html.text, 'html.parser')

# Si hay múltiples popups, podrías necesitar iterar sobre ellos o buscar el específico basado en alguna característica
popups = soup.find('div', class_='espectaculo_popup')

for popup in popups:
    if 'activo' in popup['class']:  # Asumiendo que 'activo' es una clase que indica que el popup está visible
        fecha = popup.find('li', class_='dato_fecha').p.get_text(strip=True)
        hora = popup.find('li', class_='dato_hora').p.get_text(strip=True)
        # Extrae otros datos que necesites de manera similar
        print(f"Fecha: {fecha}, Hora: {hora}")
  
popups
# Out:
# <div class="espectaculo_popup"></div>

# %%
#Ver si encuentra el precio de $6000 fuera del popup
pop = soup.find_all('p',class_='dato_fecha')
popi = soup.find_all('p')
popi

pop_precio = [p for p in popi if 'Antesala' in p.text]
pop_precio
# Out:
# []

# %%
popi
# Out:
# [<p>Sábado 13 de abril</p>,
#  <p>Medianoche | Puerta 00.30 hs</p>,
#  <p>Todos los lunes</p>,
#  <p>20 hs.</p>,
#  <p>Martes 16 de abril</p>,
#  <p>Puerta 19 hs.</p>,
#  <p>Sábado 11 de mayo </p>,
#  <p>Medianoche | Puertas 00.30 hs </p>,
#  <p>Jueves 11 de abril</p>,
#  <p>20 hs. </p>,
#  <p>Viernes 12 de abril</p>,
#  <p>20 hs. Puntual</p>,
#  <p>Viernes 12 de abril</p>,
#  <p>Medianoche | Puerta 00.30 hs.</p>,
#  <p>4, 13, 20 y 25 de abril | 3 y 11 de mayo</p>,
#  <p>20 hs. </p>,
#  <p>Domingo 14 y 28 de abril | 5 de mayo</p>,
#  <p>18 y 20 hs.</p>,
#  <p>Miércoles 17 de abril</p>,
#  <p>20 hs. </p>,
#  <p>Miércoles 10 y 17 de abril</p>,
#  <p>20:30 hs.</p>,
#  <p>Jueves 18 de abril</p>,
#  <p>20 hs. </p>,
#  <p>Viernes 19 de abril</p>,
#  <p>Puerta 18:30 hs. | Show 19:30 hs.</p>,
#  <p>Viernes 19 de abril</p>,
#  <p>Medianoche | Puerta 00.30 hs.</p>,
#  <p>Sábado 20 de abril</p>,
#  <p>Medianoche | Puerta 00.30 hs.</p>,
#  <p>Martes 23 de abril</p>,
#  <p>20 hs</p>,
# ...
